# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gdp-growth-of-african-countries/Africa_GDP.csv

# %%
# loading the data
df=pd.read_csv("/kaggle/input/gdp-growth-of-african-countries/Africa_GDP.csv")

# %%
# reviewing the data
df.head()
# Out:
#    Year       Algeria        Benin     Botswana  Burkina Faso      Burundi  \
# 0  1960  2.723615e+09  226195578.4  30411413.66   330442815.8  195999990.0
# 1  1961  2.434747e+09  235668220.5  32902612.87   350247234.3  202999992.0
# 2  1962  2.001445e+09  236434954.0  35644956.64   379567099.2  213500006.0
# 3  1963  2.702982e+09  253927697.3  38091842.85   394040667.1  232749998.0
# 4  1964  2.909316e+09  269819005.9  41616347.79   410321645.0  260750008.0
#
#       Cameroon  Central African Republic         Chad     Eswatini  ...  \
# 0  614206068.5               112155598.5  313582728.1  35076845.97  ...
# 1  652777608.3               123134583.5  333975336.1  43026042.79  ...
# 2  694247864.4               124482773.8  357635713.4  45927961.63  ...
# 3  718320845.0               129379123.8  371767002.2  54129438.35  ...
# 4  776650176.9               142025078.7  392247517.7  64980554.01  ...
#
#     Seychelles  Sierra Leone      Somalia  South Africa         Sudan  \
# ...

# %%
# checking the statistical description of the dataframe
df.describe(include="all")
# Out:
#               Year       Algeria         Benin      Botswana  Burkina Faso  \
# count    64.000000  6.400000e+01  6.400000e+01  6.400000e+01  6.400000e+01
# mean   1991.500000  7.971055e+10  4.706354e+09  5.823204e+09  5.154302e+09
# std      18.618987  7.622340e+10  5.452323e+09  6.239429e+09  5.770365e+09
# min    1960.000000  2.001445e+09  2.261956e+08  3.041141e+07  3.304428e+08
# 25%    1975.750000  1.718566e+10  6.930237e+08  3.678110e+08  9.674036e+08
# 50%    1991.500000  4.937348e+10  1.827640e+09  4.044671e+09  2.601069e+09
# 75%    2007.250000  1.444415e+11  8.510623e+09  1.023066e+10  8.081966e+09
# max    2023.000000  2.398990e+11  1.967328e+10  2.032196e+10  2.032462e+10
#
#             Burundi      Cameroon  Central African Republic          Chad  \
# count  6.400000e+01  6.400000e+01              6.400000e+01  6.400000e+01
# mean   1.170612e+09  1.484101e+10              1.097358e+09  4.011726e+09
# ...

# %%
#dataframe has no missing values
# check for the datatypes of the dataframe
df.dtypes
# Out:
# Year                          int64
# Algeria                     float64
# Benin                       float64
# Botswana                    float64
# Burkina Faso                float64
# Burundi                     float64
# Cameroon                    float64
# Central African Republic    float64
# Chad                        float64
# Eswatini                    float64
# Ethiopia                    float64
# Gabon                       float64
# Ghana                       float64
# Kenya                       float64
# Lesotho                     float64
# Liberia                     float64
# Libya                       float64
# Madagascar                  float64
# Mauritius                   float64
# Morocco                     float64
# Niger                       float64
# Nigeria                     float64
# Rwanda                      float64
# Senegal                     float64
# Seychelles                  float64
# Sierra Leone                float64
# ...

# %% [markdown]
# Exploratory Data Analysis
# <p>We explore the data to define the trend in GDP growth over the years</p>

# %%
sum_columns=df[1:].sum()
print(sum_columns)
# Out:
# Year                        1.254960e+05
# Algeria                     5.098752e+12
# Benin                       3.009805e+11
# Botswana                    3.726546e+11
# Burkina Faso                3.295449e+11
# Burundi                     7.472315e+10
# Cameroon                    9.492105e+11
# Central African Republic    7.011875e+10
# Chad                        2.564369e+11
# Eswatini                    1.123982e+11
# Ethiopia                    1.522003e+12
# Gabon                       4.358021e+11
# Ghana                       1.133831e+12
# Kenya                       1.567272e+12
# Lesotho                     6.099701e+10
# Liberia                     7.542359e+10
# Libya                       2.132738e+12
# Madagascar                  3.584169e+11
# Mauritius                   3.039650e+11
# Morocco                     3.063259e+12
# Niger                       2.733902e+11
# Nigeria                     1.025505e+13
# Rwanda                      2.057576e+11
# ...

# %%
# import other libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# The GDP trend in my country Kenya
plt.plot(df["Year"],df["Kenya"])
plt.title("GDP trend in Kenya")
plt.xlabel("Year")
plt.ylabel("GDP count")
plt.figure(figsize=(8,7.5))

# %% [markdown]
# The Kenyan Ecocnomy has significantly gronw over the years and the GDP is relatively high in the recent years .

# %%
# demonstrating the GDP of EA countries
# listing down the columnc that represent the countries
columns=df[["Kenya", "Burundi", "Uganda", "Tanzania", "Rwanda"]]
plt.figure(figsize=(12,10))

for country in columns:
    plt.plot(df["Year"], df[country], label=country)
plt.xlabel("Year")
plt.ylabel("GDP Value")
plt.title("GDP for East Africa")
plt.legend(bbox_to_anchor=(1.15, 1.0), loc="upper left", borderaxespad=0)

plt.grid()
plt.show()

# %%
# Checking the GDP growth for all the countries
cols=df.columns.tolist()[1:]
plt.figure(figsize=(8,8))
for country in cols:
    plt.plot(df["Year"], df[country], label=country)
plt.xlabel("Year")
plt.ylabel("GDP Value")
plt.title("GDP for Countries")
plt.legend(bbox_to_anchor=(1.15, 1.0), loc="upper left", borderaxespad=0)

plt.grid()
plt.show()

# %%
togo_libya=df[["Togo", "Libya"]]
for country in togo_libya:
    plt.plot(df["Year"], df[country], label=country)
plt.title("GDP Difference between Togo and Libya")
plt.xlabel("Year")
plt.ylabel("GDP Value")
plt.legend(bbox_to_anchor=(1.15, 1.0), loc="upper left", borderaxespad=0)

plt.grid()
plt.show()

# %% [markdown]
# ***Libya's GDP***-- Highest GDP Value
# <p>Libya has had an unstable GDP over the years with significant high GDP growth in the years 1970-1980 attributed to huge oil exports, then the economy was significantly unstable from 1980s to 2000s. The instability could be as an impact of the civil war and political instability in the 2000s until currently. However, Libya has recorded the highest GDP value of over 9 billion US Dollars.
# Highest GDP in the whole of Africa.</p>
